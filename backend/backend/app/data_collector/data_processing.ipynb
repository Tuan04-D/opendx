# %%
import pandas as pd
import json

# %%
file_path = r"D:\Study\OpenDX\backend\backend\app\data_collector\table_1.json"

# %%
with open(file_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#     Xếp hạng DTI Các tỉnh, thành phố trực thuộc TW  Chỉ số Nhận thức số  \
# 0              1                       TP. Đà Nẵng               1.0000
# 1              2                   TP. Hồ Chí Minh               0.8917
# 2              3                        Quảng Ninh               0.9581
# 3              4                           TP. Huế               0.9500
# 4              5                       TP. Cần Thơ               0.9000
# ..           ...                               ...                  ...
# 58            59                           Phú Yên               0.9333
# 59            60                          Bạc Liêu               0.7417
# 60            61                          Cao Bằng               0.4917
# 61            62                           Gia Lai               0.6333
# 62            63                           Bắc Kạn               0.6750
#
#     Chỉ số Thể chế số  Chỉ số Hạ tầng số  Chỉ số Nhân lực số  \
# ...

# %%
df2 = df[['Các tỉnh, thành phố trực thuộc TW', 'CHUYỂN ĐỔI SỐ CẤP TỈNH (PDTI)']]
df2.columns = ['province', 'pdti']
df2['province'] = df2['province'].str.normalize('NFKC').str.replace('TP. ', '')
df2.to_json(r'D:\Study\OpenDX\data\dti_2022_json\dti_map.json', orient='records', force_ascii=False)
# Out:
# C:\Users\TUAN PC\AppData\Local\Temp\ipykernel_24696\4057260262.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2['province'] = df2['province'].str.normalize('NFKC').str.replace('TP. ', '')
# C:\Users\TUAN PC\AppData\Local\Temp\ipykernel_24696\4057260262.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['province'] = df2['province'].str.normalize('NFKC').str.replace('TP. ', '')
